# %% [markdown]
# # Gradio Demo: english_translator

# %%
# !pip install gradio transformers torch
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# Requirement already satisfied: gradio in /tmp/.venv/lib/python3.11/site-packages (6.2.0)
# Collecting transformers
#   Downloading https://mirrors.aliyun.com/pypi/packages/6a/6b/2f416568b3c4c91c96e5a365d164f8a4a4a88030aa8ab4644181fdadce97/transformers-4.57.3-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 14.4 MB/s  0:00:00m0:00:010:01
# Collecting torch
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/be/76eaa36c9cd032d3b01b001e2c5a05943df75f26211f68fae79e62f87734/torch-2.9.1-cp311-cp311-manylinux_2_28_x86_64.whl (899.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 7.8 MB/s  0:01:156m0:00:0100:02
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.128.0)
# Requirement already satisfied: ffmpy in /tmp/.venv/lib/python3.11/site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.2 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (2.0.2)
# Requirement already satisfied: groovy~=0.1 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (1.2.3)
# Requirement already satisfied: jinja2<4.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (2.4.0)
# Requirement already satisfied: orjson~=3.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in /tmp/.venv/lib/python3.11/site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (12.1.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (2.12.5)
# Requirement already satisfied: pydub in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.0.21)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.21.0)
# Requirement already satisfied: typing-extensions~=4.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /tmp/.venv/lib/python3.11/site-packages (from gradio) (0.40.0)
# Requirement already satisfied: fsspec in /tmp/.venv/lib/python3.11/site-packages (from gradio-client==2.0.2->gradio) (2025.12.0)
# Requirement already satisfied: idna>=2.8 in /tmp/.venv/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /tmp/.venv/lib/python3.11/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /tmp/.venv/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /tmp/.venv/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /tmp/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /tmp/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /tmp/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in /tmp/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /tmp/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: typer-slim in /tmp/.venv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /tmp/.venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /tmp/.venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /tmp/.venv/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /tmp/.venv/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /tmp/.venv/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /tmp/.venv/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /tmp/.venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: rich>=10.11.0 in /tmp/.venv/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading https://mirrors.aliyun.com/pypi/packages/cb/bd/1a875e0d592d447cbc02805fd3fe0f497714d6a2583f59d14fa9ebad96eb/huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 4.6 MB/s  0:00:00
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading https://mirrors.aliyun.com/pypi/packages/61/22/b8cb00df7d2b5e0875f60628594d44dba283e951b1ae17c12f99e332cc0a/regex-2025.11.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 11.2 MB/s  0:00:00
# Requirement already satisfied: requests in /tmp/.venv/lib/python3.11/site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2e/76/932be4b50ef6ccedf9d3c6639b056a967a86258c6d9200643f01269211ca/tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 10.9 MB/s  0:00:00 eta 0:00:01
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a0/60/429e9b1cb3fc651937727befe258ea24122d9663e4d5709a48c9cbfceecb/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a2/09/77d55d46fd61b4a135c444fc97158ef34a095e5681d0a6c10b75bf356191/sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 13.3 MB/s  0:00:00 eta 0:00:01
# Collecting networkx>=2.5.1 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9e/c9/b2622292ea83fbb4ec318f5b9ab867d0a28ab43c5717bb85b0a5f6b3b0a4/networkx-3.6.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.7 MB/s  0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/05/6b/32f747947df2da6994e999492ab306a903659555dddc0fbdeb9d71f75e52/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 13.4 MB/s  0:00:06m0:00:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/0d/9b/a997b638fcd068ad6e4d53b8551a7d30fe8b404d6f1804abf1df69838932/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 9.4 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f8/02/2adcaa145158bf1a8295d83591d22e4103dbfd821bcaf6f3f53151ca4ffa/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 14.0 MB/s  0:00:00eta 0:00:01
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/ba/51/e123d997aa098c61d029f76663dedbfb9bc8dcf8c60cbd6adbe42f76d049/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 10.4 MB/s  0:00:54m0:00:0100:02
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/dc/61/e24b560ab2e2eaeb3c839129175fb330dfcfc29e5203196e5541a4c44682/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 10.8 MB/s  0:00:48m0:00:0100:02
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/1f/13/ee4e00f30e676b66ae65b4f08cb5bcbb8392c03f54f2d5413ea99a5d1c80/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 12.2 MB/s  0:00:15m0:00:0100:01
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/fb/aa/6584b56dc84ebe9cf93226a5cde4d99080c8e90ab40f0c27bda7a0f29aa1/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 12.1 MB/s  0:00:05m0:00:0100:01
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/85/48/9a13d2975803e8cf2777d5ed57b87a0b6ca2cc795f9a4f59796a910bfb80/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 12.4 MB/s  0:00:21m0:00:0100:01
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/c2/f5/e1854cb2f2bcd4280c44736c93550cc300ff4b8c95ebe370d0aa7d2b473d/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 12.3 MB/s  0:00:23m0:00:0100:01
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/79/12978b96bd44274fe38b5dde5cfb660b1d114f70a65ef962bcbbed99b549/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 12.3 MB/s  0:00:23m0:00:0100:01
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/6e/89/f7a07dc961b60645dbbf42e80f2bc85ade7feb9a491b11a1e973aa00071f/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 12.0 MB/s  0:00:26m0:00:0100:01
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/3b/6c/99acb2f9eb85c29fc6f3a7ac4dccfd992e22666dd08a642b303311326a97/nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 12.4 MB/s  0:00:10m0:00:0100:01
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/a2/eb/86626c1bbc2edb86323022371c39aa48df6fd8b0a1647bc274577f72e90b/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/f6/74/86a07f1d0f42998ca31312f998bd3b9a7eff7f52378f4f270c8679c77fb9/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 12.1 MB/s  0:00:03m0:00:0100:01
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/bb/fe/1bcba1dfbfb8d01be8d93f07bfc502c93fa23afa6fd5ab3fc7c1df71038a/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.0 MB/s  0:00:00
# Collecting triton==3.5.1 (from torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/b0/72/ec90c3519eaf168f22cb1757ad412f3a2add4782ad3a92861c9ad135d886/triton-3.5.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 12.4 MB/s  0:00:13m0:00:0100:01
# Requirement already satisfied: six>=1.5 in /tmp/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /tmp/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /tmp/.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /tmp/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading https://mirrors.aliyun.com/pypi/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.7 MB/s  0:00:00
# Requirement already satisfied: charset_normalizer<4,>=2 in /tmp/.venv/lib/python3.11/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /tmp/.venv/lib/python3.11/site-packages (from requests->transformers) (2.6.2)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, safetensors, regex, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, huggingface-hub, tokenizers, nvidia-cusolver-cu12, transformers, torch
#   Attempting uninstall: huggingface-hub╺━━━━━━━━━ 19/25 [nvidia-cudnn-cu12]12]2]2]
#     Found existing installation: huggingface_hub 1.2.3━━━━━━━━ 19/25 [nvidia-cudnn-cu12]
#     Uninstalling huggingface_hub-1.2.3:╺━━━━━━━━━ 19/25 [nvidia-cudnn-cu12]
#       Successfully uninstalled huggingface_hub-1.2.3m━━━━━━━━━ 19/25 [nvidia-cudnn-cu12]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25/25 [torch]m24/25 [torch]ormers]er-cu12]
# Successfully installed huggingface-hub-0.36.0 mpmath-1.3.0 networkx-3.6.1 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 regex-2025.11.3 safetensors-0.7.0 sympy-1.14.0 tokenizers-0.22.2 torch-2.9.1 transformers-4.57.3 triton-3.5.1

# %%
import gradio as gr

from transformers import pipeline

pipe = pipeline("translation", model="t5-base")

def translate(text):
    return pipe(text)[0]["translation_text"]  # type: ignore

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            english = gr.Textbox(label="English text")
            translate_btn = gr.Button(value="Translate")
        with gr.Column():
            german = gr.Textbox(label="German Text")

    translate_btn.click(translate, inputs=english, outputs=german, api_name="translate-to-german")
    examples = gr.Examples(examples=["I went to the supermarket yesterday.", "Helen is a good swimmer."],
                           inputs=[english])

if __name__ == "__main__":
    demo.launch()
